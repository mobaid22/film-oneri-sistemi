# %% [markdown]
# # 📊 Model Değerlendirme
#
# Bu notebook'ta eğitilen modelleri karşılaştırıyoruz.
#
# ## 📚 Kullanılacak Metrikler
#
# - RMSE (Root Mean Square Error)
# - MAE (Mean Absolute Error)
# - R² (R-Squared)

# %%
import sys
sys.path.insert(0, '..')

from src.recommender import FilmOneriSistemi

# Sistem oluştur
sistem = FilmOneriSistemi()
sistem.veri_yukle()
sistem.veri_bol(test_orani=0.2)

# %% [markdown]
# ## Model Karşılaştırması

# %%
# Tüm modelleri karşılaştır
sonuclar = sistem.tum_modelleri_karsilastir()

# %% [markdown]
# ## ✅ Sonuç
#
# En düşük RMSE değerine sahip model en iyi!
#
# **Sonraki Notebook:** `06_problemler_cozumler.ipynb` - Problemler ve Çözümler
